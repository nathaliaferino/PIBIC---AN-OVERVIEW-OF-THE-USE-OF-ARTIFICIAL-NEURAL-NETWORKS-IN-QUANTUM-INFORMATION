# %% [markdown]
# <a href="https://colab.research.google.com/github/nathaliaferino/PIBIC---AN-OVERVIEW-OF-THE-USE-OF-ARTIFICIAL-NEURAL-NETWORKS-IN-QUANTUM-INFORMATION/blob/main/DATASET_EMARANHAMENTO_QU%C3%82NTICO_PARA_SISTEMAS_DE_DOIS_QUBITS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('teste')
# Out:
# teste
